# %%
import os

# %%
import pandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-38d4b0363d82> in <module>
# ----> 1 import pandas
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas

# %%
pic_table = pandas.read_excel('ClaraPix/ClaraPics.xlsx')

# %%
pic_table[2:5]
# Out:
#    img #     Wer Hilfe von       Title                Key    Datum  \
# 2       3  Clara       NaN      Muster             Schule  Juli 18
# 3       4  Clara       NaN      Pythor  Ninjago, Schlange  Juli 18
# 4       5  Clara       NaN  Herzmuster        Herz, Kunst  Juli 18
#
#   Datum unbekannt                        Note  Set
# 2             NaN  Was Clara alles schon kann  NaN
# 3             NaN         Vielleicht von Juno  NaN
# 4             NaN                         NaN  NaN

# %%
pic_table[2:15]
# Out:
#     img #     Wer Hilfe von  \
# 2        3  Clara       NaN
# 3        4  Clara       NaN
# 4        5  Clara       NaN
# 5        6  Clara       NaN
# 6        7  Clara       NaN
# 7        8  Clara       NaN
# 8        9  Clara       NaN
# 9       10  Clara       NaN
# 10      11  Clara       NaN
# 11      12  Clara       NaN
# 12      13  Clara       NaN
# 13      14  Clara       NaN
# 14      15  Clara       NaN
#
#                                                 Title                    Key  \
# 2                                              Muster                 Schule
# 3                                              Pythor      Ninjago, Schlange
# 4                                          Herzmuster            Herz, Kunst
# 5                                     Skizze Tänzerin                   Tanz
# 6                                 Clara an der Straße          Clara, Sommer
# 7                                              Muster                  Kunst
# ...
